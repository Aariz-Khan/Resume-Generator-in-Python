# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.figure(figsize=(11.69,8.27))
fontfam = 'sans-serif'
fontStix = "font."+ fontfam
plt.rcParams['font.family'] = fontfam
plt.rcParams[fontStix] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.27 ,11.69),dpi=100)
fig.patch.set_visible(False)
ax.set_axis_off()
plt.axis()
Image = plt.imread("test.png")
plt.imshow(Image)
